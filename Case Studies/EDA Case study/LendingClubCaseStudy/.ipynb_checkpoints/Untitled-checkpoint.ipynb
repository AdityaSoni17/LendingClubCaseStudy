# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loan_df = pd.read_csv('loan.csv')
# Out:
# /var/folders/n3/cbql2_sd28n7ws76wtd_mphw0000gn/T/ipykernel_46973/3086117574.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_df = pd.read_csv('loan.csv')

# %%
loan_df.head(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
plt.boxplot(loan_df.loan_amnt)
#plt.boxplot(loan_df.loan_status.describe())
print(loan_df.loan_amnt.describe())
# Out:
# count    39717.000000
# mean     11219.443815
# std       7456.670694
# min        500.000000
# 25%       5500.000000
# 50%      10000.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
loan_df.loan_status.value_counts()['Fully Paid']
# Out:
# 32950

# %%
loan_df.loan_status.value_counts().plot()
# Out:
# <Axes: xlabel='loan_status'>

# %%
plt.hist(loan_df['loan_amnt'],bins=35)
# Adding and formatting title
plt.title("Loan Amount Request\n", fontdict={'fontsize': 20, 'fontweight' : 20, 'color' : 'Green'})

# Labeling Axes
plt.xlabel("Loan Amunt", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})
plt.ylabel("Count", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})

plt.show()

# %%
# explode = (0, 0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Very good')
# plt.figure(figsize = [8,8])

# plt.pie(loan_df.loan_status.value_counts()['Fully Paid'], explode=explode, labels=['Fully Paid'], autopct='%1.1f%%', 
#         textprops={'fontsize': 16, 'fontweight' : 20, 'color' : 'Black'}, startangle=90)

# # Adding and formatting title
# plt.title("Distribution based on quality of cut\n", fontdict={'fontsize': 20, 'fontweight' : 20, 'color' : 'Green'})

# plt.show()
loan_df.loan_status.value_counts().items
# Out:
# <bound method Series.items of loan_status
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: count, dtype: int64>

# %%
#df2 = loan_df.loan_amnt
year = np.array(['2011','2010','2009','2008','2007'])
loan_issued = df2.value_counts().values

plt.bar(['2011','2010','2009','2008','2007'], df2.value_counts().values)
plt.title("Loan Issued", fontdict={'fontsize': 20, 'fontweight' : 20, 'color' : 'Green'})

# Labeling Axes
plt.xlabel("Year", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})
plt.ylabel("Count of Loan Issued", fontdict={'fontsize': 12, 'fontweight' : 20, 'color' : 'Brown'})

for xy in zip(year, loan_issued):
    plt.annotate(text="{}K".format(xy[1] // 1000),  
                 xy=xy,
                 textcoords='data',
                 ha='center') 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #df2 = loan_df.loan_amnt
#       2 year = np.array(['2011','2010','2009','2008','2007'])
# ----> 3 loan_issued = df2.value_counts().values
#       5 plt.bar(['2011','2010','2009','2008','2007'], df2.value_counts().values)
#       6 plt.title("Loan Issued", fontdict={'fontsize': 20, 'fontweight' : 20, 'color' : 'Green'})
#
# NameError: name 'df2' is not defined

# %%
df2 = loan_df['loan_amnt']#.apply(lambda x: int(x.split('-')[1]))
df2
# Out:
# 0         5000
# 1         2500
# 2         2400
# 3        10000
# 4         3000
#          ...
# 39712     2500
# 39713     8500
# 39714     5000
# 39715     5000
# 39716     7500
# Name: loan_amnt, Length: 39717, dtype: int64

# %%
df = loan_df
Fully_Paid = df[df['loan_status'] =='Fully Paid']['loan_status'].describe()
#Charged_Off = np.array([df[(df['loan_status'] =='Charged Off')]])
#Current = np.array([df[(df['loan_status'] =='Current')]])
print(Fully_Paid)
#print(Charged_Off)
#print(Current)
#plt.boxplot([Fully_Paid,Charged_Off, Current], vert=False)  
plt.boxplot(df['loan_status'].value_counts(), vert=False)
# Out:
# count          32950
# unique             1
# top       Fully Paid
# freq           32950
# Name: loan_status, dtype: object
# {'whiskers': [<matplotlib.lines.Line2D at 0x16a2223c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16a2226c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16a222120>],
#  'medians': [<matplotlib.lines.Line2D at 0x16a2230b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16a223320>],
#  'means': []}

# %%
df = loan_df

# %%
def status_flag(x):
    if x== 'Fully Paid':
        return 1
    elif x=='Charged Off':
        return 2
    elif x=='Current':
        return 3
    else:
        return 0
df['status_flag'] = df['loan_status'].apply(lambda x:status_flag(x))

# %%
plt.boxplot(df['status_flag'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16a2c26f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16a2c2cc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16a064fb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16a2c3110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16a2c3380>],
#  'means': []}

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: count, dtype: int64

# %%
df.home_ownership.value_counts().to_dict()
# Out:
# {'RENT': 18899, 'MORTGAGE': 17659, 'OWN': 3058, 'OTHER': 98, 'NONE': 3}

# %%
sns.catplot(data=df,kind='bar',x='loan_status',y='home_ownership')

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np
home_ownership = ("RENT","MORTGAGE","OWN","OTHER","NONE")#("Adelie", "Chinstrap", "Gentoo")
loan_status = df['loan_status']
x = np.arange(len(home_ownership))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0
fig, ax = plt.subplots(layout='constrained')
for status, status_count in loan_status.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, status_count, width, label=status)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Count')
ax.set_title('Home Ownership')
ax.set_xticks(x + width, home_ownership)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 50000)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 14
#      12     offset = width * multiplier
#      13     rects = ax.bar(x + offset, status_count, width, label=status)
# ---> 14     ax.bar_label(rects, padding=3)
#      15     multiplier += 1
#      17 # Add some text for labels, title and custom x-axis tick labels, etc.
#
# File ~/Downloads/Upgrade/Python/virtual_env/course_env/lib/python3.12/site-packages/matplotlib/axes/_axes.py:2821, in Axes.bar_label(self, container, labels, fmt, label_type, padding, **kwargs)
#    2817     if key in kwargs:
#    2818         raise ValueError(
#    2819             f"Passing {key!r} to bar_label() is not supported.")
# -> 2821 a, b = self.yaxis.get_view_interval()
#    2822 y_inverted = a > b
#    2823 c, d = self.xaxis.get_view_interval()
#
# ...

# %%
sns.heatmap(df.loc[:,['loan_amnt','installment','annual_inc','funded_amnt','funded_amnt_inv']].describe().corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(df,x='loan_amnt',bins=20,kde=True, kde_kws=dict(cut=0),
    alpha=.4, edgecolor=(1, 1, 1, .6),hue='loan_status')
plt.show()

# %%
sns.displot(df,x='addr_state',bins=40,kde=True, kde_kws=dict(cut=0),
    alpha=.5, edgecolor=(1, 1, 1, .6),color='orange',hue='loan_status' ,height=5, aspect=3.8)
plt.show()

# %%
sns.displot(data=df2,x=df2.grade.value_counts().to_dict().keys(),y=df2.groupby('grade').value_counts(),hue='sub_grade')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n3/cbql2_sd28n7ws76wtd_mphw0000gn/T/ipykernel_46973/3381871671.py in ?()
# ----> 1 sns.displot(data=df2,x=df2.grade.value_counts().to_dict().keys(),y=df2.groupby('grade').value_counts(),hue='sub_grade')
#
# ~/Downloads/Upgrade/Python/virtual_env/course_env/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'grade'

# %%
df.sub_grade.value_counts()
# Out:
# sub_grade
# B3    2917
# A4    2886
# A5    2742
# B5    2704
# B4    2512
# C1    2136
# B2    2057
# C2    2011
# B1    1830
# A3    1810
# C3    1529
# A2    1508
# D2    1348
# C4    1236
# C5    1186
# D3    1173
# A1    1139
# D4     981
# D1     931
# D5     874
# E1     763
# E2     656
# E3     553
# E4     454
# E5     416
# F1     329
# F2     249
# F3     185
# F4     168
# F5     118
# G1     104
# G2      78
# G4      56
# G3      48
# G5      30
# Name: count, dtype: int64

# %%
df.grade.value_counts().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='grade'>

# %%
df2 = df.loc[:,['grade','sub_grade']].set_index(df.grade.value_counts().to_dict().keys())
df2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Downloads/Upgrade/Python/virtual_env/course_env/lib/python3.12/site-packages/pandas/core/frame.py:6112, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6111 try:
# -> 6112     found = col in self.columns
#    6113 except TypeError as err:
#
# File ~/Downloads/Upgrade/Python/virtual_env/course_env/lib/python3.12/site-packages/pandas/core/indexes/base.py:5358, in Index.__contains__(self, key)
#    5324 """
#    5325 Return a boolean indicating whether the provided key is in the index.
#    5326
#    (...)
#    5356 False
#    5357 """
# -> 5358 hash(key)
#    5359 try:
#
# TypeError: unhashable type: 'dict_keys'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
df2.groupby('grade').value_counts().plot(kind='bar', stacked=True,color=['red', 'skyblue', 'green'])

# %%
df3 = df2.groupby('grade').value_counts()

# %%
df3

# %%
df4= df.loc[:,['grade','sub_grade']]
df4.value_counts().plot(kind='bar',stacked=True,x=df4.grade)

# %%
sns.barplot(x='grade',y='sub_grade',data=df,estimator=sum)
# Out:
# <Axes: xlabel='grade', ylabel='sub_grade'>

# %%
#add all sub grade values inside the grade values kind of concatation but separation with the stacked graph in the seaborn
grades = df.grade
sub_grades = df.sub_grade

# %%
total = grades+'-'+sub_grades

# %%
total.unique()
grades.unique()
# Out:
# array(['B', 'C', 'A', 'E', 'F', 'D', 'G'], dtype=object)

# %%
#df['loan_status'].to_dict()

# %%
loan_status = [df[df['home_ownership']=='RENT']['loan_status'].value_counts().to_dict(),
              df[df['home_ownership']=='MORTGAGE']['loan_status'].value_counts().to_dict(),
               df[df['home_ownership']=='OWN']['loan_status'].value_counts().to_dict(),
               df[df['home_ownership']=='OTHER']['loan_status'].value_counts().to_dict(),
               df[df['home_ownership']=='NONE']['loan_status'].value_counts().to_dict()
              ]
stat = {
        'Fully Paid': [],
        'Charged Off': [],
        'Current': []
}
for i in loan_status:
    #print(i)
    #if len(i.items())
    if 'Fully Paid' not in i.keys():
        i['Fully Paid'] = 0
    if 'Charged Off' not in i.keys():
        i['Charged Off'] = 0
    if 'Current' not in i.keys():
        i['Current'] = 0
    stat['Fully Paid'].append(i['Fully Paid'])
    stat['Charged Off'].append(i['Charged Off'])
    stat['Current'].append(i['Current'])   
stat
# Out:
# {'Fully Paid': [15641, 14694, 2532, 80, 3],
#  'Charged Off': [2839, 2327, 443, 18, 0],
#  'Current': [419, 638, 83, 0, 0]}

# %%
import matplotlib.pyplot as plt
import numpy as np
home_ownership = ("RENT","MORTGAGE","OWN","OTHER","NONE")
loan_status = stat
x = np.arange(len(home_ownership))  # the label locations
width = 0.25  # the width of the bars
multiplier = 1
fig, ax = plt.subplots(layout='constrained')
for status, status_count in loan_status.items():
        offset = width * multiplier
        rects = ax.bar(x + offset, status_count, width, label=status)
        ax.bar_label(rects, padding=2)
        multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Count')
ax.set_xlabel('Home Ownership')
ax.set_xticks(x + width, home_ownership)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 18000)
plt.show()

# %%
grade = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter, MultipleLocator
import seaborn as sns
import pandas as pd
sns.set_style('whitegrid')

stacked_df=df.loc[df.index.repeat(df.Assigned)]  ##Used repeate to create rows as value in repeat

g = sns.displot(data=df1, x='Yield', hue='Phylum', col='Season', multiple='fill', shrink=0.7, stat='probability', palette='turbo') ##stat is probability
g.set(xlabel='', ylabel='')
g.axes[0, 0].yaxis.set_major_locator(MultipleLocator(.1))
g.axes[0, 0].yaxis.set_major_formatter(PercentFormatter(1))
g.axes[0, 0].set_xlim(-.6, 1.6)
sns.despine(left=True)
plt.subplots_adjust(wspace=0)
plt.show()

# %%
ax = sns.histplot(
    loan_df,
    x='grade',
    # Use the value variable here to turn histogram counts into weighted
    # values.
    #weights='sub_grade',
    hue='loan_status',
    multiple='stack',
    palette=['#efa929', '#ae24d1','#59a967'],
    # Add white borders to the bars.
    edgecolor='white',
    # Shrink the bars a bit so they don't touch.
    shrink=0.8
)

ax.set_title('Loan Payment based on Grade')
# Remove 'Count' ylabel.
ax.set_ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
group_data = loan_df.groupby('verification_status').count()

# Create lists which hold the necessary data
x_vals = []
y_vals = []
for i in range(len(group_data)): 
    # The elements in the list are arranged in increasing order of the quality of cut. 
    # This information can be gathered from the data dictionary.  
    x_vals.append(group_data.index[i])
    y_vals.append(group_data.iloc[i,0])
explode = (0, 0, 0.1)  # only "explode" the 2nd slice (i.e. 'Very good')
plt.figure(figsize = [5,5])

plt.pie(y_vals, explode=explode, labels=x_vals, autopct='%1.1f%%', 
        textprops={'fontsize': 16, 'fontweight' : 20, 'color' : 'Black'}, startangle=90)

# Adding and formatting title
plt.title("Verification Status\n", fontdict={'fontsize': 20, 'fontweight' : 20, 'color' : 'Green'})

plt.show()

# %%
x_vals = []
y_vals = []
for i in range(len(group_data)): 
    # The elements in the list are arranged in increasing order of the quality of cut. 
    # This information can be gathered from the data dictionary.  
    x_vals.append(group_data.index[i])
    y_vals.append(group_data.iloc[i,0])

# %%
grade_group_data = loan_df.groupby('grade')

# %%
grade_group_data['sub_grade'].count()
#sub_grade.value_counts()
ax = sns.histplot(
    loan_df,
    x='grade',
    # Use the value variable here to turn histogram counts into weighted
    # values.
    #weights='sub_grade',
    hue='sub_grade',
    multiple='stack',
    palette=['#efa929', '#ae24d1','#59a967','#39a967','#a9a967'],
    # Add white borders to the bars.
    edgecolor='white',
    # Shrink the bars a bit so they don't touch.
    shrink=0.5
)
plt.legend(['1','2','3','4','5'])
ax.set_title('sub grade count based on Grade')
# Remove 'Count' ylabel.
ax.set_ylabel(None)
# Out:
# /var/folders/n3/cbql2_sd28n7ws76wtd_mphw0000gn/T/ipykernel_46973/80613337.py:3: UserWarning:
# The palette list has fewer values (5) than needed (35) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.histplot(
# Text(0, 0.5, '')

# %%
loan_df['rate'] = loan_df['int_rate'].apply(lambda x: float(x.replace('%','')))

# %%
loan_df['rate']
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: rate, Length: 39717, dtype: float64

# %%
ax = sns.histplot(
    loan_df,
    x='rate',
    # Use the value variable here to turn histogram counts into weighted
    # values.
    #weights='sub_grade',
    # hue='sub_grade',
    # multiple='stack',
    # palette=['#efa929', '#ae24d1','#59a967','#39a967','#a9a967'],
    # Add white borders to the bars.
    edgecolor='white',
    color = '#59a967',
    # Shrink the bars a bit so they don't touch.
    shrink=1
    ,bins=5
)
# plt.legend(['1','2','3','4','5'])
ax.set_title('Interest Rate')
# Remove 'Count' ylabel.
ax.set_ylabel('Count')
rate_range = loan_df['rate'].describe().to_dict()
#remove(['count','mean','std'])
del rate_range['count']
del rate_range['mean']
del rate_range['std']
rate_range.values()
# for xy in zip(rate_range.values(),rate_range.values()):
#     plt.annotate(text="{}%".format(xy[1]),  
#                  xy=xy,
#                  textcoords='data',
#                  ha='left')
# Out:
# dict_values([5.42, 9.25, 11.86, 14.59, 24.59])

# %%
rate_range = loan_df['rate'].describe().to_dict()
#remove(['count','mean','std'])
del rate_range['count']
del rate_range['mean']
del rate_range['std']
rate_range.values()
# Out:
# dict_values([5.42, 9.25, 11.86, 14.59, 24.59])

# %%
# generate histogram

# a histogram returns 3 objects : n (i.e. frequncies), bins, patches
freq, bins, patches = plt.hist(d, edgecolor='white', label='d', bins=range(1,101,10))

# x coordinate for labels
bin_centers = np.diff(bins)*0.5 + bins[:-1]

n = 0
for fr, x, patch in zip(freq, bin_centers, patches):
  height = int(freq[n])
  plt.annotate("{}".format(height),
               xy = (x, height),             # top left corner of the histogram bar
               xytext = (0,0.2),             # offsetting label position above its bar
               textcoords = "offset points", # Offset (in points) from the *xy* value
               ha = 'center', va = 'bottom'
               )
  n = n+1

plt.legend()
plt.show;
